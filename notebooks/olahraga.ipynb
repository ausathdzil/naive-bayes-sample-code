# %%
import pandas as pd

df = pd.read_excel('../raw/prob_olahraga.xlsx')  # pyright: ignore[reportUnknownMemberType]
print(df.head())
# Out:
#    Cuaca Temperatur Kecepatan Angin Berolahraga
# 0  Cerah     Normal           Pelan          Ya
# 1  Cerah     Normal           Pelan          Ya
# 2  Hujan     Tinggi           Pelan       Tidak
# 3  Cerah     Normal         Kencang          Ya
# 4  Hujan     Tinggi         Kencang       Tidak
